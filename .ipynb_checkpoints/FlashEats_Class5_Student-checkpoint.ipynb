# %% [markdown]
# # FlashEats — Class 5 Investigation
#
# ## Client escalation
#
# > **“Late deliveries are increasing and customers say our ETA is unreliable. Figure out what is happening before we invest in an AI delay-prediction system.”**
#
# Today is not a syntax lesson. Your job is to use SQL, CSV, JSON and APIs like an FDE:
#
# **define the question → retrieve evidence → validate completeness → reconcile sources → state what you know and what you still cannot know**
#
# ### Rules
# - Do not train an ML model.
# - State your definition of **late** before calculating it.
# - Preserve raw API responses.
# - Do not silently drop failures.
# - If another team gets a different answer, investigate the definition and data grain first.

# %%
# 0. INSTALLS + IMPORTS
# !pip -q install pandas requests flask matplotlib

import os, sys, json, time, sqlite3, subprocess, zipfile
from pathlib import Path

import pandas as pd
import requests
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_colwidth", 120)

print("Environment ready.")
# Out:
# WARNING: Ignoring invalid distribution ~andas (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~andas (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Environment ready.

# %%
# 1. LOAD THE CLASSROOM PACK
# In Colab, upload FlashEats_Classroom_Pack.zip when prompted.

BASE = Path("/Users/akshatsipany/SST/fde/flasheats-classroom-pack")

if not BASE.exists():
    try:
        from google.colab import files
        print("Upload FlashEats_Classroom_Pack.zip")
        uploaded = files.upload()
        zip_name = next(name for name in uploaded if name.endswith(".zip"))
        with zipfile.ZipFile(zip_name, "r") as z:
            z.extractall("/content")
    except Exception as e:
        print("If running locally, set BASE manually to the extracted pack.")
        print(e)

print("BASE:", BASE)
print("Exists:", BASE.exists())
# Out:
# BASE: /Users/akshatsipany/SST/fde/flasheats-classroom-pack
# Exists: True

# %% [markdown]
# ## 2. Source map first
#
# Before analysis, predict where you would look for:
#
# | Information | Likely source | Why? |
# |---|---|---|
# | Promised delivery time |  |  |
# | Actual delivery time |  |  |
# | Driver assignment |  |  |
# | Customer complaint |  |  |
# | Restaurant status |  |  |
# | Driver movement/events |  |  |
#
# **Discuss:** Which source is authoritative for each fact, and which is only contextual?

# %%
# 3. BASIC SYNTAX — READ EVERY SOURCE

# SQLite
db_path = BASE / "database" / "flasheats.db"
con = sqlite3.connect(db_path)

tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;",
    con
)
display(tables)

sample_orders = pd.read_sql("SELECT * FROM orders LIMIT 5;", con)
display(sample_orders)

# CSV
tickets = pd.read_csv(BASE / "data" / "support_tickets.csv")
restaurant_status = pd.read_csv(BASE / "data" / "restaurant_status.csv")
display(tickets.head())

# Nested JSON
with open(BASE / "data" / "driver_events.json", "r") as f:
    driver_events = json.load(f)

print("Driver objects:", len(driver_events))
display(driver_events[:1])
# Out:
#           name
# 0    customers
# 1      drivers
# 2       orders
# 3  restaurants
#   order_id customer_id restaurant_id driver_id       city  \
# 0   O00001       C0168          R009      D103  Bengaluru
# 1   O00002       C0043          R018      D083  Bengaluru
# 2   O00003       C0855          R010      D039  Bengaluru
# 3   O00004       C0229          R030      D038  Bengaluru
# 4   O00005       C0040          R004      D047  Bengaluru
#
#             created_at                promised_eta  \
# 0  2026-08-13T12:56:00         2026-08-13T14:11:36
# 1  2026-08-01T18:36:00  2026-08-01T19:43:16.627988
# 2  2026-08-01T19:35:00  2026-08-01T20:17:52.941967
# 3  2026-08-09T18:16:00  2026-08-09T19:30:19.067006
# 4  2026-08-06T20:35:00         2026-08-06T21:54:48
#
#                     pickup_at          actual_delivery_at final_status  \
# 0  2026-08-13T13:35:49.825561  2026-08-13T14:22:25.035899    delivered
# 1  2026-08-01T18:58:24.735336  2026-08-01T19:47:14.818533    delivered
# 2  2026-08-01T19:57:50.820366  2026-08-01T20:13:28.061191    delivered
# 3  2026-08-09T18:46:48.725485                         NaN    cancelled
# 4  2026-08-06T21:18:38.024280  2026-08-06T22:15:49.290713    delivered
#
#    distance_km_estimate traffic_bucket weather_bucket
# 0                 18.00         medium          clear
# 1                  9.37         severe          clear
# 2                  2.42         medium          clear
# 3                 14.20           high           rain
# 4                 18.00           high          clear
#   ticket_id order_id           created_at           category  \
# 0    T00001   O00006  2026-08-26T23:34:00      late_delivery
# 1    T00002   O00018  2026-08-24T13:49:00        eta_changed
# 2    T00003   O00034  2026-08-25T18:22:00    status_mismatch
# 3    T00004   O00037  2026-08-09T21:09:00  driver_not_moving
# 4    T00005   O00040  2026-08-11T20:15:00      late_delivery
#
#                                                customer_message
# 0                   My order is already past the promised time.
# 1        The ETA keeps changing and the food is still not here.
# 2  The app says picking up but the restaurant says it is ready.
# 3                       The rider has not moved for 15 minutes.
# 4                   My order is already past the promised time.
# Driver objects: 120
# [{'driver_id': 'D001',
#   'events': [{'order_id': 'O00162',
#     'type': 'assigned',
#     'timestamp': '2026-08-26T17:53:25.977803'},
#    {'order_id': 'O00162',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-26T18:10:59.372420',
#     'lat': 12.826339,
#     'lon': 77.448282},
#    {'order_id': 'O00162',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-26T18:28:32.767037',
#     'lat': 12.876013,
#     'lon': 77.477707},
#    {'order_id': 'O00162',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-26T18:46:06.161653',
#     'lat': 12.925686,
#     'lon': 77.507133},
#    {'order_id': 'O00162',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-26T19:03:39.556270',
#     'lat': 12.97536,
#     'lon': 77.536558},
#    {'order_id': 'O00162',
#     'type': 'picked_up',
#     'timestamp': '2026-08-26T18:27:32.131791'},
#    {'order_id': 'O00162',
#     'type': 'delivered',
#     'timestamp': '2026-08-26T19:21:12.950887'},
#    {'order_id': 'O00180',
#     'type': 'assigned',
#     'timestamp': '2026-08-08T18:05:08.439625'},
#    {'order_id': 'O00180',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-08T18:28:19.378257',
#     'lat': 13.073469,
#     'lon': 77.716653},
#    {'order_id': 'O00180',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-08T18:51:30.316889',
#     'lat': 13.071031,
#     'lon': 77.659475},
#    {'order_id': 'O00180',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-08T19:14:41.255521',
#     'lat': 13.068592,
#     'lon': 77.602296},
#    {'order_id': 'O00180',
#     'type': 'picked_up',
#     'timestamp': '2026-08-08T18:43:23.314022'},
#    {'order_id': 'O00180',
#     'type': 'delivered',
#     'timestamp': '2026-08-08T19:37:52.194153'},
#    {'order_id': 'O00189',
#     'type': 'assigned',
#     'timestamp': '2026-08-15T16:36:59.082592'},
#    {'order_id': 'O00189',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-15T16:58:58.547755',
#     'lat': 12.98655,
#     'lon': 77.619687},
#    {'order_id': 'O00189',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-15T17:20:58.012919',
#     'lat': 13.015691,
#     'lon': 77.636248},
#    {'order_id': 'O00189',
#     'type': 'picked_up',
#     'timestamp': '2026-08-15T17:06:55.662026'},
#    {'order_id': 'O00189',
#     'type': 'delivered',
#     'timestamp': '2026-08-15T17:42:57.478082'},
#    {'order_id': 'O00327',
#     'type': 'assigned',
#     'timestamp': '2026-08-19T20:27:19.053446'},
#    {'order_id': 'O00327',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T20:41:15.483033',
#     'lat': 12.945385,
#     'lon': 77.432752},
#    {'order_id': 'O00327',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T20:55:11.912619',
#     'lat': 12.933066,
#     'lon': 77.479674},
#    {'order_id': 'O00327',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:09:08.342206',
#     'lat': 12.920748,
#     'lon': 77.526597},
#    {'order_id': 'O00327',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:23:04.771793',
#     'lat': 12.908429,
#     'lon': 77.57352},
#    {'order_id': 'O00327',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:25:01.201379',
#     'lat': 12.89611,
#     'lon': 77.620442},
#    {'order_id': 'O00327',
#     'type': 'picked_up',
#     'timestamp': '2026-08-19T20:50:44.724434'},
#    {'order_id': 'O00327',
#     'type': 'delivered',
#     'timestamp': '2026-08-19T21:50:57.630966'},
#    {'order_id': 'O00374',
#     'type': 'assigned',
#     'timestamp': '2026-08-19T17:12:31.845744'},
#    {'order_id': 'O00374',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T17:28:16.336337',
#     'lat': 12.854727,
#     'lon': 77.597486},
#    {'order_id': 'O00374',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T17:44:00.826930',
#     'lat': 12.85739,
#     'lon': 77.624214},
#    {'order_id': 'O00374',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T17:59:45.317523',
#     'lat': 13.360054,
#     'lon': 78.150943},
#    {'order_id': 'O00374',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T18:15:29.808116',
#     'lat': 12.862717,
#     'lon': 77.677671},
#    {'order_id': 'O00374',
#     'type': 'picked_up',
#     'timestamp': '2026-08-19T17:34:20.116953'},
#    {'order_id': 'O00374',
#     'type': 'delivered',
#     'timestamp': '2026-08-19T18:31:14.298709'},
#    {'order_id': 'O00496',
#     'type': 'assigned',
#     'timestamp': '2026-08-04T15:09:01.658960'},
#    {'order_id': 'O00496',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T15:17:00.802320',
#     'lat': 13.072777,
#     'lon': 77.560158},
#    {'order_id': 'O00496',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T15:24:59.945680',
#     'lat': 13.065783,
#     'lon': 77.600114},
#    {'order_id': 'O00496',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T15:32:59.089041',
#     'lat': 13.058789,
#     'lon': 77.640071},
#    {'order_id': 'O00496',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T15:40:58.232401',
#     'lat': 13.051795,
#     'lon': 77.680027},
#    {'order_id': 'O00496',
#     'type': 'picked_up',
#     'timestamp': '2026-08-04T14:59:12.709125'},
#    {'order_id': 'O00496',
#     'type': 'delivered',
#     'timestamp': '2026-08-04T15:48:57.375761'},
#    {'order_id': 'O00581',
#     'type': 'assigned',
#     'timestamp': '2026-08-24T19:12:02.061732'},
#    {'order_id': 'O00581',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-24T19:18:38.317252',
#     'lat': 12.987155,
#     'lon': 77.479824},
#    {'order_id': 'O00581',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-24T19:25:14.572772',
#     'lat': 12.985428,
#     'lon': 77.479057},
#    {'order_id': 'O00581',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-24T19:31:50.828292',
#     'lat': 12.983702,
#     'lon': 77.47829},
#    {'order_id': 'O00581',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-24T19:38:27.083812',
#     'lat': 12.981975,
#     'lon': 77.477522},
#    {'order_id': 'O00581',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-24T19:45:03.339332',
#     'lat': 12.980248,
#     'lon': 77.476755},
#    {'order_id': 'O00581',
#     'type': 'picked_up',
#     'timestamp': '2026-08-24T19:37:35.329796'},
#    {'order_id': 'O00581',
#     'type': 'delivered',
#     'timestamp': '2026-08-24T19:51:39.594852'},
#    {'order_id': 'O00711',
#     'type': 'assigned',
#     'timestamp': '2026-08-17T16:25:27.642973'},
#    {'order_id': 'O00711',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-17T16:41:20.079438',
#     'lat': 12.882653,
#     'lon': 77.584095},
#    {'order_id': 'O00711',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-17T16:57:12.515903',
#     'lat': 12.922778,
#     'lon': 77.557732},
#    {'order_id': 'O00711',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-17T17:13:04.952367',
#     'lat': 12.962904,
#     'lon': 77.531368},
#    {'order_id': 'O00711',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-17T17:28:57.388832',
#     'lat': 13.003029,
#     'lon': 77.505005},
#    {'order_id': 'O00711',
#     'type': 'picked_up',
#     'timestamp': '2026-08-17T16:41:33.445791'},
#    {'order_id': 'O00711',
#     'type': 'delivered',
#     'timestamp': '2026-08-17T17:44:49.825297'},
#    {'order_id': 'O00788',
#     'type': 'assigned',
#     'timestamp': '2026-08-03T11:59:08.236656'},
#    {'order_id': 'O00788',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T12:17:12.073923',
#     'lat': 12.9737,
#     'lon': 77.64987},
#    {'order_id': 'O00788',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T12:35:15.911189',
#     'lat': 12.946921,
#     'lon': 77.648703},
#    {'order_id': 'O00788',
#     'type': 'picked_up',
#     'timestamp': '2026-08-03T12:16:34.129996'},
#    {'order_id': 'O00788',
#     'type': 'delivered',
#     'timestamp': '2026-08-03T12:53:19.748456'},
#    {'order_id': 'O00896',
#     'type': 'assigned',
#     'timestamp': '2026-08-14T12:21:07.009032'},
#    {'order_id': 'O00896',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-14T12:54:12.037718',
#     'lat': 12.999867,
#     'lon': 77.599598},
#    {'order_id': 'O00896',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-14T13:27:17.066404',
#     'lat': 13.0099,
#     'lon': 77.555568},
#    {'order_id': 'O00896',
#     'type': 'picked_up',
#     'timestamp': '2026-08-14T13:15:49.285212'},
#    {'order_id': 'O00896',
#     'type': 'delivered',
#     'timestamp': '2026-08-14T14:00:22.095090'},
#    {'order_id': 'O00956',
#     'type': 'assigned',
#     'timestamp': '2026-08-19T18:14:45.492679'},
#    {'order_id': 'O00956',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T18:26:19.619776',
#     'lat': 12.970842,
#     'lon': 77.676553},
#    {'order_id': 'O00956',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T18:37:53.746874',
#     'lat': 13.003384,
#     'lon': 77.672012},
#    {'order_id': 'O00956',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T18:49:27.873971',
#     'lat': 13.035927,
#     'lon': 77.66747},
#    {'order_id': 'O00956',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T19:01:02.001068',
#     'lat': 13.068469,
#     'lon': 77.662928},
#    {'order_id': 'O00956',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T19:12:36.128166',
#     'lat': 13.101012,
#     'lon': 77.658387},
#    {'order_id': 'O00956',
#     'type': 'picked_up',
#     'timestamp': '2026-08-19T18:42:16.480735'},
#    {'order_id': 'O00956',
#     'type': 'delivered',
#     'timestamp': '2026-08-19T19:24:10.255263'},
#    {'order_id': 'O00973',
#     'type': 'assigned',
#     'timestamp': '2026-08-04T19:40:54.927451'},
#    {'order_id': 'O00973',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T19:52:38.363558',
#     'lat': 13.02552,
#     'lon': 77.65866},
#    {'order_id': 'O00973',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T20:04:21.799664',
#     'lat': 13.010462,
#     'lon': 77.667157},
#    {'order_id': 'O00973',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T20:16:05.235771',
#     'lat': 12.995404,
#     'lon': 77.675654},
#    {'order_id': 'O00973',
#     'type': 'picked_up',
#     'timestamp': '2026-08-04T20:01:41.203903'},
#    {'order_id': 'O00973',
#     'type': 'delivered',
#     'timestamp': '2026-08-04T20:27:48.671877'},
#    {'order_id': 'O00991',
#     'type': 'assigned',
#     'timestamp': '2026-08-19T20:45:15.978801'},
#    {'order_id': 'O00991',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T20:58:45.644168',
#     'lat': 13.106497,
#     'lon': 77.453102},
#    {'order_id': 'O00991',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:12:15.309534',
#     'lat': 13.100385,
#     'lon': 77.49604},
#    {'order_id': 'O00991',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:25:44.974901',
#     'lat': 13.094272,
#     'lon': 77.538977},
#    {'order_id': 'O00991',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:39:14.640267',
#     'lat': 13.088159,
#     'lon': 77.581914},
#    {'order_id': 'O00991',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-19T21:52:44.305634',
#     'lat': 13.082047,
#     'lon': 77.624852},
#    {'order_id': 'O00991',
#     'type': 'picked_up',
#     'timestamp': '2026-08-19T21:18:06.123295'},
#    {'order_id': 'O00991',
#     'type': 'delivered',
#     'timestamp': '2026-08-19T22:06:13.971000'},
#    {'order_id': 'O01019',
#     'type': 'assigned',
#     'timestamp': '2026-08-18T16:25:01.366867'},
#    {'order_id': 'O01019',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-18T16:42:01.068765',
#     'lat': 12.798656,
#     'lon': 77.554473},
#    {'order_id': 'O01019',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-18T16:59:00.770662',
#     'lat': 12.858342,
#     'lon': 77.594128},
#    {'order_id': 'O01019',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-18T17:04:00.472560',
#     'lat': 12.918027,
#     'lon': 77.633783},
#    {'order_id': 'O01019',
#     'type': 'picked_up',
#     'timestamp': '2026-08-18T16:34:00.966668'},
#    {'order_id': 'O01019',
#     'type': 'delivered',
#     'timestamp': '2026-08-18T17:33:00.174458'},
#    {'order_id': 'O01170',
#     'type': 'assigned',
#     'timestamp': '2026-08-05T20:26:24.384390'},
#    {'order_id': 'O01170',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-05T20:42:28.401578',
#     'lat': 12.973917,
#     'lon': 77.51845},
#    {'order_id': 'O01170',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-05T20:58:32.418767',
#     'lat': 13.005263,
#     'lon': 77.541168},
#    {'order_id': 'O01170',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-05T21:14:36.435955',
#     'lat': 13.03661,
#     'lon': 77.563886},
#    {'order_id': 'O01170',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-05T21:30:40.453144',
#     'lat': 13.067957,
#     'lon': 77.586604},
#    {'order_id': 'O01170',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-05T21:46:44.470333',
#     'lat': 13.099303,
#     'lon': 77.609322},
#    {'order_id': 'O01170',
#     'type': 'picked_up',
#     'timestamp': '2026-08-05T20:59:27.055004'},
#    {'order_id': 'O01170',
#     'type': 'delivered',
#     'timestamp': '2026-08-05T22:02:48.487521'},
#    {'order_id': 'O01200',
#     'type': 'assigned',
#     'timestamp': '2026-08-13T22:39:55.375426'},
#    {'order_id': 'O01200',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-13T22:51:18.596463',
#     'lat': 12.931142,
#     'lon': 77.73941},
#    {'order_id': 'O01200',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-13T23:02:41.817500',
#     'lat': 12.918663,
#     'lon': 77.706867},
#    {'order_id': 'O01200',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-13T23:14:05.038537',
#     'lat': 12.906184,
#     'lon': 77.674324},
#    {'order_id': 'O01200',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-13T23:25:28.259574',
#     'lat': 12.893704,
#     'lon': 77.641782},
#    {'order_id': 'O01200',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-13T23:36:51.480611',
#     'lat': 12.881225,
#     'lon': 77.609239},
#    {'order_id': 'O01200',
#     'type': 'picked_up',
#     'timestamp': '2026-08-13T23:03:46.146230'},
#    {'order_id': 'O01200',
#     'type': 'delivered',
#     'timestamp': '2026-08-13T23:48:14.701648'},
#    {'order_id': 'O01244',
#     'type': 'assigned',
#     'timestamp': '2026-08-02T22:13:18.179357'},
#    {'order_id': 'O01244',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-02T22:27:00.853687',
#     'lat': 12.878232,
#     'lon': 77.719107},
#    {'order_id': 'O01244',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-02T22:40:43.528017',
#     'lat': 12.902745,
#     'lon': 77.687085},
#    {'order_id': 'O01244',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-02T22:54:26.202348',
#     'lat': 12.927258,
#     'lon': 77.655063},
#    {'order_id': 'O01244',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-02T23:08:08.876678',
#     'lat': 12.951771,
#     'lon': 77.623042},
#    {'order_id': 'O01244',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-02T23:21:51.551008',
#     'lat': 12.976284,
#     'lon': 77.591021},
#    {'order_id': 'O01244',
#     'type': 'picked_up',
#     'timestamp': '2026-08-02T22:40:01.538575'},
#    {'order_id': 'O01244',
#     'type': 'delivered',
#     'timestamp': '2026-08-02T23:35:34.225338'},
#    {'order_id': 'O01257',
#     'type': 'assigned',
#     'timestamp': '2026-08-15T14:55:23.346785'},
#    {'order_id': 'O01257',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-15T15:22:45.374625',
#     'lat': 13.09196,
#     'lon': 77.763495},
#    {'order_id': 'O01257',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-15T15:50:07.402466',
#     'lat': 13.02502,
#     'lon': 77.684852},
#    {'order_id': 'O01257',
#     'type': 'picked_up',
#     'timestamp': '2026-08-15T15:21:03.506155'},
#    {'order_id': 'O01257',
#     'type': 'delivered',
#     'timestamp': '2026-08-15T16:17:29.430306'},
#    {'order_id': 'O01264',
#     'type': 'assigned',
#     'timestamp': '2026-08-04T20:59:50.336217'},
#    {'order_id': 'O01264',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T21:14:27.666588',
#     'lat': 13.061113,
#     'lon': 77.70643},
#    {'order_id': 'O01264',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T21:29:04.996960',
#     'lat': 13.046318,
#     'lon': 77.639028},
#    {'order_id': 'O01264',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-04T21:43:42.327331',
#     'lat': 13.031523,
#     'lon': 77.571627},
#    {'order_id': 'O01264',
#     'type': 'picked_up',
#     'timestamp': '2026-08-04T21:08:27.291882'},
#    {'order_id': 'O01264',
#     'type': 'delivered',
#     'timestamp': '2026-08-04T21:58:19.657702'},
#    {'order_id': 'O01439',
#     'type': 'assigned',
#     'timestamp': '2026-08-03T11:40:07.132333'},
#    {'order_id': 'O01439',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T11:48:30.452029',
#     'lat': 12.911774,
#     'lon': 77.60243},
#    {'order_id': 'O01439',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T11:56:53.771725',
#     'lat': 12.904172,
#     'lon': 77.593976},
#    {'order_id': 'O01439',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T12:05:17.091421',
#     'lat': 12.896569,
#     'lon': 77.585521},
#    {'order_id': 'O01439',
#     'type': 'gps_ping',
#     'timestamp': '2026-08-03T12:13:40.411117',
#     'lat': 12.888967,
#     'lon': 77.577067},
#    {'order_id': 'O01439',
#     'type': 'picked_up',
#     'timestamp': '2026-08-03T11:58:22.891428'},
#    {'order_id': 'O01439',
#     'type': 'delivered',
#     'timestamp': '2026-08-03T12:22:03.730813'}]}]

# %% [markdown]
# # Challenge 1 — How large is the late-delivery problem?
#
# Before coding, decide:
#
# - **Late means:** ______________________________
# - **Denominator:** _____________________________
# - **Cancelled orders:** include / exclude / other?
# - **Missing actual delivery timestamp:** what will you do?
# - **Row grain:** what does one row represent?
#
# ### Required analysis
# 1. valid delivered orders,
# 2. late count and percentage,
# 3. median lateness among late orders,
# 4. worst delayed orders,
# 5. any data-quality issue that changes the metric.

# %%
# Starter syntax only — complete the analysis yourself.

# (Previous SQL approach — commented out)
# query = """
# SELECT *
# FROM orders
# LIMIT 20;
# """
# queryCnt = """
# SELECT COUNT(*) as valid_delivered_orders from (
#     SELECT *
#     FROM orders
#     WHERE final_status = 'delivered' and actual_delivery_at != 'NaN'
# );
# """
# all_orders = pd.read_sql(query, con)

# ---- New approach: load the table ONCE, do everything in pandas ----
all_orders = pd.read_sql("SELECT * FROM orders", con)
# display(all_orders.head(20))   # replaces the old "LIMIT 20" preview query

# Useful pandas syntax:
# df["timestamp"] = pd.to_datetime(df["timestamp"], format="mixed", errors="coerce")
# df["delay_min"] = (df["actual"] - df["promised"]).dt.total_seconds() / 60
# df["order_id"].duplicated().sum()
# df.isna().sum()

# ---- Challenge 1 analysis (pandas-only) ----

# (Previous: orders_preview = pd.read_sql(queryCnt, con); valid_count = ...iloc[0])
all_orders = all_orders.drop_duplicates("order_id",keep="first").copy()
valid_orders = all_orders[
    (all_orders["final_status"] == "delivered") &
    (all_orders["actual_delivery_at"].notna())
]
valid_count = len(valid_orders)
print("Valid delivered orders count : ", valid_count)

# (Previous: late_query / late_cnt_query via pd.read_sql)
late_orders = valid_orders[
    valid_orders["actual_delivery_at"] > valid_orders["promised_eta"]
]
late_cnt = len(late_orders)

print("Late delivered orders count : ", late_cnt)
print("Late pct : ", round((late_cnt / valid_count) * 100, 2))

# Timestamp parsing + delay computation (same as before)
late_orders = late_orders.copy()  # avoid SettingWithCopyWarning
late_orders["actual"] = pd.to_datetime(late_orders["actual_delivery_at"], format="mixed")
late_orders["promised"] = pd.to_datetime(late_orders["promised_eta"], format="mixed")
late_orders["delay_min"] = (late_orders["actual"] - late_orders["promised"]).dt.total_seconds() / 60

median_lateness = late_orders["delay_min"].median()
print("Lateness Median: ", round(median_lateness, 2))

worst_late_orders = late_orders[
    late_orders["delay_min"] > 0
].sort_values(by="delay_min",ascending= False).head(10)
display(worst_late_orders)
# Out:
# Valid delivered orders count :  1495
# Late delivered orders count :  843
# Late pct :  56.39
# Lateness Median:  7.94
#      order_id customer_id restaurant_id driver_id       city  \
# 1080   O01081       C0554          R048      D082  Bengaluru
# 472    O00473       C0719          R002      D064  Bengaluru
# 1101   O01102       C0634          R021      D010  Bengaluru
# 193    O00194       C0771          R020      D018  Bengaluru
# 1311   O01312       C0206          R027      D056  Bengaluru
# 1402   O01403       C0497          R014      D099  Bengaluru
# 459    O00460       C0087          R026      D104  Bengaluru
# 736    O00737       C0824          R027      D048  Bengaluru
# 63     O00064       C0265          R002      D032  Bengaluru
# 197    O00198       C0657          R016      D100  Bengaluru
#
#                created_at                promised_eta  \
# 1080  2026-08-13T17:14:00  2026-08-13T18:15:46.613098
# 472   2026-08-14T18:58:00         2026-08-14T20:17:48
# 1101  2026-08-12T18:25:00  2026-08-12T19:31:12.651822
# 193   2026-08-11T17:36:00         2026-08-11T19:01:48
# 1311  2026-08-14T19:02:00         2026-08-14T20:17:36
# 1402  2026-08-24T17:26:00         2026-08-24T18:47:36
# 459   2026-08-12T16:27:00         2026-08-12T17:52:24
# 736   2026-08-20T20:10:00  2026-08-20T21:11:15.896462
# 63    2026-08-09T19:22:00  2026-08-09T20:29:56.928762
# 197   2026-08-19T18:07:00  2026-08-19T18:57:33.382886
#
#                        pickup_at          actual_delivery_at final_status  \
# 1080  2026-08-13T18:19:53.467196  2026-08-13T19:06:02.677891    delivered
# 472   2026-08-14T20:05:22.631148  2026-08-14T21:04:00.769224    delivered
# 1101  2026-08-12T19:31:48.324377  2026-08-12T20:16:09.835907    delivered
# 193   2026-08-11T18:31:39.836812  2026-08-11T19:40:08.111510    delivered
# 1311  2026-08-14T20:03:23.614086  2026-08-14T20:54:36.321890    delivered
# 1402  2026-08-24T18:17:58.127167  2026-08-24T19:24:32.047659    delivered
# 459   2026-08-12T17:21:45.188189  2026-08-12T18:29:16.970368    delivered
# 736   2026-08-20T21:14:02.973657  2026-08-20T21:47:32.398594    delivered
# 63    2026-08-09T20:20:33.032412  2026-08-09T21:05:34.486949    delivered
# 197   2026-08-19T19:02:58.154574  2026-08-19T19:32:47.457048    delivered
#
#       distance_km_estimate traffic_bucket weather_bucket  \
# 1080                  9.42           high          clear
# 472                  18.00           high          clear
# 1101                 13.53         medium          clear
# 193                  18.00           high     heavy_rain
# 1311                 18.00         medium          clear
# 1402                 18.00         medium     heavy_rain
# 459                  18.00         severe          clear
# 736                  12.51            low          clear
# 63                   14.36         medium          clear
# 197                   6.07         medium          clear
#
#                          actual                   promised  delay_min
# 1080 2026-08-13 19:06:02.677891 2026-08-13 18:15:46.613098  50.267747
# 472  2026-08-14 21:04:00.769224 2026-08-14 20:17:48.000000  46.212820
# 1101 2026-08-12 20:16:09.835907 2026-08-12 19:31:12.651822  44.953068
# 193  2026-08-11 19:40:08.111510 2026-08-11 19:01:48.000000  38.335192
# 1311 2026-08-14 20:54:36.321890 2026-08-14 20:17:36.000000  37.005365
# 1402 2026-08-24 19:24:32.047659 2026-08-24 18:47:36.000000  36.934128
# 459  2026-08-12 18:29:16.970368 2026-08-12 17:52:24.000000  36.882839
# 736  2026-08-20 21:47:32.398594 2026-08-20 21:11:15.896462  36.275036
# 63   2026-08-09 21:05:34.486949 2026-08-09 20:29:56.928762  35.625970
# 197  2026-08-19 19:32:47.457048 2026-08-19 18:57:33.382886  35.234569

# %% [markdown]
# ## Checkpoint
#
# Compare your answer with another team.
#
# If your counts differ, investigate:
# - duplicate rows,
# - cancelled orders,
# - missing timestamps,
# - late-delivery definition,
# - row grain.

# %% [markdown]
# # Challenge 2 — Operations says: “Traffic is the problem.”
#
# Test that claim using at least three dimensions.
#
# Possible dimensions:
# - traffic,
# - weather,
# - distance,
# - time of day,
# - restaurant,
# - driver.
#
# ### Required output
# - 2–3 comparisons,
# - one chart or compact table,
# - one hypothesis supported by evidence,
# - one alternative explanation you cannot rule out.
#
# Separate **association** from **causation**.

# %%
# Starter ideas:
# df.groupby("traffic_bucket")["delay_min"].agg(["count","median","mean"])
# df.groupby("weather_bucket")["delay_min"].agg(["count","median","mean"])

# Example plotting syntax:
# summary.plot(kind="bar")
# plt.title("...")
# plt.show()

# TODO: your Challenge 2 analysis
all_orders.info()
all_orders_valid_time = all_orders[all_orders["actual_delivery_at"].notna()].copy()
all_orders_valid_time["actual"] = pd.to_datetime(all_orders_valid_time["actual_delivery_at"], format="mixed")
all_orders_valid_time["promised"] = pd.to_datetime(all_orders_valid_time["promised_eta"], format="mixed")

all_orders_valid_time["delay_min"] = (all_orders_valid_time["actual"] - all_orders_valid_time["promised"]).dt.total_seconds() / 60
# display(all_orders_valid_time)

all_orders_group_traffic = all_orders_valid_time.groupby("traffic_bucket")["delay_min"].agg(["count" , "median" , "mean"])
all_orders_group_weather = all_orders_valid_time.groupby("weather_bucket")["delay_min"].agg(["count" , "median" , "mean"])

display(all_orders_group_traffic)
display(all_orders_group_weather)

import seaborn as sns


sns.barplot(data=all_orders_valid_time,x = "traffic_bucket" , y = "delay_min",legend=True)
sns.barplot(data=all_orders_valid_time,x = "weather_bucket" , y = "delay_min",legend=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              1600 non-null   str
#  1   customer_id           1600 non-null   str
#  2   restaurant_id         1600 non-null   str
#  3   driver_id             1600 non-null   str
#  4   city                  1600 non-null   str
#  5   created_at            1600 non-null   str
#  6   promised_eta          1600 non-null   str
#  7   pickup_at             1600 non-null   str
#  8   actual_delivery_at    1495 non-null   str
#  9   final_status          1600 non-null   str
#  10  distance_km_estimate  1600 non-null   float64
#  11  traffic_bucket        1600 non-null   str
#  12  weather_bucket        1600 non-null   str
# dtypes: float64(1), str(12)
# memory usage: 381.5 KB
#                 count    median      mean
# traffic_bucket
# high              422  3.765266  5.087764
# low               360 -0.094586  0.915365
# medium            589  0.311237  1.836523
# severe            124  4.265774  6.397665
#                 count    median      mean
# weather_bucket
# clear            1192  0.741715  2.001686
# heavy_rain         72  6.629961  7.745551
# rain              231  4.228268  6.094810
# <Axes: xlabel='traffic_bucket', ylabel='delay_min'>

# %% [markdown]
# # Challenge 3 — Customer Support disagrees
#
# Use `support_tickets.csv`.
#
# ### Questions
# 1. What are customers actually complaining about?
# 2. Which complaint types are most common?
# 3. Are ticket IDs unique?
# 4. Does the customer story match the operational story?
# 5. What can tickets tell you that timestamps cannot?
#
# ### Required output
# A short **system view vs customer view** comparison.

# %%
display(tickets.head())

print("Complaint categories:")
display(tickets["category"].value_counts())

print("Duplicate ticket IDs:")
print(tickets["ticket_id"].duplicated().sum())

# Join syntax if useful:
# merged = tickets.merge(order_analysis, on="order_id", how="left")

# TODO: compare support evidence with delivery analysis

# %% [markdown]
# # Challenge 4 — Dispatch API: prove you retrieved everything
#
# Your task:
# 1. start the API,
# 2. inspect one response,
# 3. retrieve **all** records,
# 4. handle pagination,
# 5. handle retryable failures,
# 6. save every successful raw page,
# 7. prove ingestion completeness.
#
# A successful HTTP `200` on one page does **not** prove the job succeeded.

# %%
# Start the mock API
api_script = BASE / "api" / "mock_dispatch_api.py"

api_proc = subprocess.Popen(
    [sys.executable, str(api_script)],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)

time.sleep(2)
health = requests.get("http://127.0.0.1:8000/health", timeout=10)
print(health.status_code, health.json())

# %%
# Basic API syntax
API_URL = "http://127.0.0.1:8000/dispatch/orders"

response = requests.get(
    API_URL,
    params={"page": 1, "page_size": 50},
    timeout=10
)

print("HTTP:", response.status_code)

if response.ok:
    payload = response.json()
    print("Keys:", payload.keys())
    print("Records on page:", len(payload["data"]))
    print("Has more:", payload["has_more"])
    print("Reported total:", payload["total_records"])

# %%
# TODO: reliable paginated ingestion

RAW_DIR = BASE / "student_output" / "raw_dispatch"
RAW_DIR.mkdir(parents=True, exist_ok=True)

def fetch_all_dispatch_orders():
    """
    Requirements:
    - fetch every page,
    - retry HTTP 500 / 429,
    - preserve successful raw responses,
    - fail clearly on unrecoverable errors,
    - verify final record count.
    """
    records = []

    # Suggested skeleton:
    # page = 1
    # while True:
    #     response = requests.get(...)
    #     if response.status_code in [429, 500]:
    #         ...
    #     response.raise_for_status()
    #     payload = response.json()
    #     save payload
    #     records.extend(payload["data"])
    #     if not payload["has_more"]:
    #         break
    #     page += 1

    return records

# dispatch_records = fetch_all_dispatch_orders()
# print("Retrieved:", len(dispatch_records))

# %% [markdown]
# # Challenge 5 — Can we attribute the delay?
#
# Inspect `driver_events.json`.
#
# Look for:
# - assignment,
# - GPS pings,
# - pickup,
# - delivery.
#
# Then answer:
#
# > **Can we reliably tell when the driver arrived at the restaurant?**
#
# Be precise about:
# - **Observed** = directly stored.
# - **Inferred** = estimated from another signal, such as GPS.
#
# ### Required output
#
# | Event / fact | Observed? | Source | Reliability concern |
# |---|---|---|---|
# | Driver assigned |  |  |  |
# | Driver at restaurant |  |  |  |
# | Picked up |  |  |  |
# | Delivered |  |  |  |

# %%
first_driver = driver_events[0]
print("Driver:", first_driver["driver_id"])
display(pd.DataFrame(first_driver["events"]).head(15))

# Flatten nested JSON
flat_events = []
for driver in driver_events:
    for event in driver["events"]:
        flat_events.append({"driver_id": driver["driver_id"], **event})

driver_events_df = pd.DataFrame(flat_events)
display(driver_events_df.head())

print("Event types:")
display(driver_events_df["type"].value_counts())

# TODO: can you find an explicit driver_arrived_at_restaurant event?

# %% [markdown]
# # Final FDE synthesis — one slide only
#
# Your final slide must answer:
#
# 1. **Problem size** — how large is the late-delivery problem?
# 2. **Evidence** — what appears related to delay?
# 3. **Trusted sources** — which sources do you trust for which facts?
# 4. **Uncertainty** — what can you not determine confidently?
# 5. **Instrumentation recommendation** — what should FlashEats capture/fix next?
# 6. **Decision** — would you build the AI delay predictor now? Why or why not?
#
# Use language such as:
# - “The data shows…”
# - “This is associated with…”
# - “We cannot determine…”
# - “We would need X before concluding Y…”

# %%
# Optional cleanup
try:
    con.close()
except:
    pass

try:
    api_proc.terminate()
except:
    pass

print("Session cleanup complete.")
